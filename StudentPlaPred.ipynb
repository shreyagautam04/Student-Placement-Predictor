# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyagautam04/Student-Placement-Predictor/blob/main/StudentPlaPred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown --quiet

# %%
import gdown

# Get this from your CSV file in Drive: right-click → Share → Copy link
file_url = 'https://drive.google.com/file/d/14UhdQHIayYOlnJ_aro8mMP3PUulCHMFh/view?usp=sharing'

# gdown needs just the file ID, extracted from that link
file_id = file_url.split('/d/')[1].split('/')[0]
gdown.download(f'https://drive.google.com/uc?id={file_id}', 'Contact Information.csv', quiet=False)

import pandas as pd
df = pd.read_csv('Contact Information.csv')
df.head()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=14UhdQHIayYOlnJ_aro8mMP3PUulCHMFh
# To: /content/Contact Information.csv
# 100%|██████████| 35.9k/35.9k [00:00<00:00, 16.0MB/s]
#                         Timestamp Gender  Age                 Branch  \
# 0  2026/07/10 3:25:23 pm GMT+5:30    NaN  NaN                    CSE
# 1  2026/07/10 3:28:26 pm GMT+5:30    NaN  NaN                    CSE
# 2  2026/07/10 3:33:12 pm GMT+5:30    NaN  NaN  CCV (Cloud Computing)
# 3  2026/07/10 3:34:50 pm GMT+5:30    NaN  NaN                    CSE
# 4  2026/07/10 3:36:09 pm GMT+5:30    NaN  NaN                    CSE
#
#   College Tier    CGPA  Rate your Coding Skills (out of 10)  \
# 0       Tier-3  08-Sep                                    9
# 1       Tier-3  06-Jul                                    7
# 2       Tier-3  09-Oct                                   10
# 3       Tier-3  09-Oct                                    9
# 4       Tier-3  06-Jul                                    5
#
# ...
